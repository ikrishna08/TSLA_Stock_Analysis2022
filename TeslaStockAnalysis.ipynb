# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
tsla_df = pd.read_csv("TSLA.csv")

# %%
print(tsla_df.head())
print(tsla_df.info())
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2956 entries, 0 to 2955
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2956 non-null   object
#  1   Open       2956 non-null   float64
#  2   High       2956 non-null   float64
#  3   Low        2956 non-null   float64
#  4   Close      2956 non-null   float64
#  5   Adj Close  2956 non-null   float64
#  6   Volume     2956 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 161.8+ KB
# None

# %%
if 'Date' in tsla_df.columns:
    tsla_df['Date'] = pd.to_datetime(tsla_df['Date'])

# %%
tsla_df['Price Change'] = tsla_df['Close'].pct_change()
tsla_df.dropna(inplace=True)

# %%
features = ['Open', 'High', 'Low', 'Close', 'Volume']
X = tsla_df[features]
y = tsla_df['Target']

# %%
features = ['Open', 'High', 'Low', 'Close', 'Volume']
X = tsla_df[features]
y = tsla_df['Close'].shift(-1)  # Predict next day's closing price

# %%
tsla_df.dropna(inplace=True)

# %%
y_pred = model.predict(X_test)

# %%
X_train, X_test, y_train, y_test = train_test_split(X[:-1], y[:-1], test_size=0.2, random_state=42)

# %%
plt.figure(figsize=(8, 5))
feature_importances = pd.Series(model.feature_importances_, index=features)
feature_importances.nlargest(5).plot(kind='barh', color='blue')
plt.title("Feature Importance in Stock Prediction")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(tsla_df['Close'], bins=50, kde=True, color='blue')
plt.title("Distribution of Closing Prices")
plt.xlabel("Close Price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(12, 6))
tsla_df.set_index('Date')['Close'].plot(title="Stock Price Over Time", color='green')
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.show()
